# %%
import requests

with open('Pictures/bermuda.jpg', 'rb') as f:
    response = requests.post('http://localhost:8786/detect', files={'imagefile': f})
    
detections = response.json()

# %%
detections
# Out:
# {'gaussian': {'confidences': [0.9980623722076416,
#    0.9981221556663513,
#    0.9981120228767395,
#    0.9980618357658386,
#    0.998081386089325,
#    0.9981241822242737,
#    0.9981811046600342],
#   'objects': [[['person', 0.9196977615356445],
#     ['person', 0.9855219721794128],
#     ['person', 0.9980313777923584],
#     ['person', 0.9980623722076416]],
#    [['person', 0.917258083820343],
#     ['person', 0.984948992729187],
#     ['person', 0.9981036186218262],
#     ['person', 0.9981221556663513]],
#    [['person', 0.9138723015785217],
#     ['person', 0.9849960803985596],
#     ['person', 0.9980277419090271],
#     ['person', 0.9981120228767395]],
#    [['person', 0.9261687397956848],
#     ['person', 0.9840841889381409],
#     ['person', 0.9980618357658386]],
#    [['person', 0.9180265069007874],
#     ['person', 0.9832959771156311],
#     ['person', 0.998081386089325]],
#    [['person', 0.9119285345077515],
#     ['person', 0.9852763414382935],
# ...
